# %%
from pydna.gel import gel
from Bio.Seq import Seq
from pydna.dseqrecord import Dseqrecord
from pydna.ladders import PennStateLadder

# %%
plasmid_1 = Dseqrecord('...')
plasmid_2 = Dseqrecord('...')
plasmid_3 = Dseqrecord('...')
plasmid_4 = Dseqrecord('...')
plasmid_5 = Dseqrecord('...')

# %%
gel([PennStateLadder,[Dseqrecord("A"*2000)]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/bn/ftdvykdx40s4mf6jdttwbql40000gn/T/ipykernel_17076/236892271.py in <module>
# ----> 1 gel([PennStateLadder,[Dseqrecord("A"*2000)]])
#       2
#
# TypeError: 'Image' object is not callable
